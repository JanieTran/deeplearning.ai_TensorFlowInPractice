# %% [markdown]
# Below is code with a link to a happy or sad dataset which contains 80 images, 40 happy and 40 sad.
# Create a convolutional neural network that trains to 100% accuracy on these images,  which cancels training upon hitting training accuracy of >.999
#
# Hint -- it will work best with 3 convolutional layers.

# %%
import tensorflow as tf
import os
# import zipfile


DESIRED_ACCURACY = 0.999

# !wget --no-check-certificate \
#     "https://storage.googleapis.com/laurencemoroney-blog.appspot.com/happy-or-sad.zip" \
#     -O "/tmp/happy-or-sad.zip"

# zip_ref = zipfile.ZipFile("/tmp/happy-or-sad.zip", 'r')
# zip_ref.extractall("/tmp/h-or-s")
# zip_ref.close()

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epochs, logs={}):
    if logs.get('accuracy') > DESIRED_ACCURACY:
      print('\n\nReached 99.9%% accuracy!')
      self.model.stop_training = True

callbacks = myCallback()

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense
from tensorflow.keras.optimizers import RMSprop

# This Code Block should Define and Compile the Model
model = tf.keras.models.Sequential([
    Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPool2D(pool_size=2, strides=2),
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu'),
    MaxPool2D(pool_size=2, strides=2),
    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    MaxPool2D(pool_size=2, strides=2),
    Flatten(),
    Dense(units=256, activation='relu'),
    Dense(units=1, activation='sigmoid')
])

model.compile(optimizer=RMSprop(lr=1e-3), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# This code block should create an instance of an ImageDataGenerator called train_datagen 
# And a train_generator by calling train_datagen.flow_from_directory

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_directory(
        'tmp/happy-or-sad/',
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary'
)

# Expected output: 'Found 80 images belonging to 2 classes'
# Out:
# Found 80 images belonging to 2 classes.

# %%
# This code block should call model.fit_generator and train for
# a number of epochs. 
history = model.fit_generator(
      train_generator,
      steps_per_epoch=8,
      epochs=15,
      verbose=1,
      callbacks=[callbacks]
)
    
# Expected output: "Reached 99.9% accuracy so cancelling training!""
# Out:
# Epoch 1/15
# 8/8 [==============================] - 1s 133ms/step - loss: 1.1100 - accuracy: 0.5529
# Epoch 2/15
# 8/8 [==============================] - 1s 136ms/step - loss: 0.4245 - accuracy: 0.7991
# Epoch 3/15
# 8/8 [==============================] - 1s 127ms/step - loss: 0.1987 - accuracy: 0.9471
# Epoch 4/15
# 8/8 [==============================] - 1s 120ms/step - loss: 0.1495 - accuracy: 0.9471
# Epoch 5/15
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0909 - accuracy: 0.9732
# Epoch 6/15
# 8/8 [==============================] - 1s 122ms/step - loss: 0.0798 - accuracy: 0.9760
# Epoch 7/15
# 8/8 [==============================] - 1s 120ms/step - loss: 0.0284 - accuracy: 0.9952
# Epoch 8/15
# 7/8 [=========================>....] - ETA: 0s - loss: 0.0147 - accuracy: 1.0000
#
# Reached 99.9%% accuracy!
# 8/8 [==============================] - 1s 124ms/step - loss: 0.0153 - accuracy: 1.0000
